# %% [markdown]
# # Process Image

# %%
import matplotlib.pyplot as plt

from pkg.model import Model

from pkg.pipeline import prepare_dataset
from pkg.pipeline import get_prediction_ranking
from pkg.pipeline import process_image
# Out:
# 2023-03-15 12:13:51.495040: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
#data directory here!
data_dir = "dataset/ringsranking"

#ranking file
ranking_url = "dataset/ringsranking.xlsx"

#pickle file
pickle_url = "ringsranking.pickle"

# %%
images, ringsranking_images_prediction_df = prepare_dataset(data_dir, ranking_url, pickle_url)

# %%
idx = 4
image = images[idx]
name, prediction, ranking = get_prediction_ranking(idx, ringsranking_images_prediction_df)

g_images = []
g_one_images = []
g_two_images = []
g_three_images = []

g_titles = ["Grayscale", "Polar", "Polar Pith", "Sobel", "Sobel(blur)", "Canny", "Canny(otsu)", "Canny(triangle)", 
            "Canny(manual)", "Canny(blur)", "Canny(blur otsu)", "Canny(blur triangle)", "Canny(blur manual)", "Laplacian", "Laplacian(blur)", 
            "Polar Sobel", "Polar Sobel(blur)", "Polar Canny", "Polar Canny(otsu)", "Polar Canny(triangle)", 
            "Polar Canny(manual)", "Polar Canny(blur)", "Polar Canny(blur otsu)", "Polar Canny(blur triangle)", "Polar Canny(blur manual)", "Polar Laplacian", "Polar Laplacian(blur)",  
            "Polar Pith Sobel", "Polar Pith Sobel(blur)", "Polar Pith Canny", "Polar Pith Canny(otsu)", 
            "Polar Pith Canny(riangle)", "Polar Pith Canny(manual)", "Polar Pith Canny(blur)", 
            "Polar Pith Canny(blur otsu)", "Polar Pith Canny(blur triangle)", "Polar Pith Canny(blur manual)", "Polar Pith Laplacian", "Polar Pith Laplacian(blur)"]

g_one_titles = ["Grayscale", "Polar", "Polar Pith", "Sobel", "Sobel(blur)", "Canny", "Canny(otsu)", "Canny(triangle)", 
            "Canny(manual)", "Canny(blur)", "Canny(blur otsu)", "Canny(blur triangle)", "Canny(blur manual)", "Laplacian", "Laplacian(blur)"]

g_two_titles = ["Polar Sobel", "Polar Sobel(blur)", "Polar Canny", "Polar Canny(otsu)", "Polar Canny(triangle)", 
            "Polar Canny(manual)", "Polar Canny(blur)", "Polar Canny(blur otsu)", "Polar Canny(blur triangle)", 
                "Polar Canny(blur manual)", "Polar Laplacian", "Polar Laplacian(blur)"]

g_three_titles = ["Polar Pith Sobel", "Polar Pith Sobel(blur)", "Polar Pith Canny", "Polar Pith Canny(otsu)", 
            "Polar Pith Canny(riangle)", "Polar Pith Canny(manual)", "Polar Pith Canny(blur)", 
            "Polar Pith Canny(blur otsu)", "Polar Pith Canny(blur triangle)", "Polar Pith Canny(blur manual)", "Polar Pith Laplacian", "Polar Pitth Laplacian(blur)"]

# %%
gray_image, polar_image, edge_image = process_image(Model.GRAYSCALE, prediction, image)
g_images.append(gray_image)
g_one_images.append(gray_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR, prediction, image)
g_images.append(polar_image)
g_one_images.append(polar_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH, prediction, image)
g_images.append(polar_image)
g_one_images.append(polar_image)

gray_image, polar_image, edge_image = process_image(Model.SOBEL_EDGE, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.SOBEL_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_OTSU, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_MANUAL, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_BLUR_OTSU, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_BLUR_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.CANNY_EDGE_BLUR_MANUAL, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.LAPLACIAN_EDGE, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.LAPLACIAN_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_one_images.append(edge_image)



gray_image, polar_image, edge_image = process_image(Model.POLAR_SOBEL_EDGE, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_SOBEL_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_OTSU, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_MANUAL, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_BLUR_OTSU, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_BLUR_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_CANNY_EDGE_BLUR_MANUAL, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_LAPLACIAN_EDGE, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_LAPLACIAN_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_two_images.append(edge_image)


gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_SOBEL_EDGE, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_SOBEL_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_OTSU, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_MANUAL, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_BLUR_OTSU, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_BLUR_TRIANGLE, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_CANNY_EDGE_BLUR_MANUAL, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_LAPLACIAN_EDGE, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

gray_image, polar_image, edge_image = process_image(Model.POLAR_PITH_LAPLACIAN_EDGE_BLUR, prediction, image)
g_images.append(edge_image)
g_three_images.append(edge_image)

# %%
rows = 13
columns = 3


fig = plt.figure(figsize=(6,20))

col_index = 1
for i in range(3):
    
    img = g_images[i]
    title = g_titles[i]
    
    fig.add_subplot(rows, columns, col_index)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    col_index += 1

for i in range(12):
    
    img = g_images[i+3]
    title = g_titles[i+3]
    
    fig.add_subplot(rows, columns, col_index)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    
    img = g_images[i+15]
    title = g_titles[i+15]
    
    fig.add_subplot(rows, columns, col_index+1)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    
    img = g_images[i+27]
    title = g_titles[i+27]
    
    fig.add_subplot(rows, columns, col_index+2)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    
    col_index += 3

plt.show()

# %%
rows = 5
columns = 3


fig = plt.figure(figsize=(6,8))

col_index = 1
for i in range(15):
    
    img = g_one_images[i]
    title = g_one_titles[i]
    
    fig.add_subplot(rows, columns, col_index)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    col_index += 1

plt.show()

plt.show()

# %%
rows = 4
columns = 3


fig = plt.figure(figsize=(6,8))

col_index = 1
for i in range(12):
    
    img = g_two_images[i]
    title = g_two_titles[i]
    
    fig.add_subplot(rows, columns, col_index)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    col_index += 1

plt.show()

plt.show()

# %%
rows = 4
columns = 3

fig = plt.figure(figsize=(6,8))

col_index = 1
for i in range(12):
    
    img = g_three_images[i]
    title = g_three_titles[i]
    
    fig.add_subplot(rows, columns, col_index)
    plt.imshow(img,cmap='gray')
    plt.title(title, fontsize = 8)
    plt.axis('off')
    col_index += 1

plt.show()

plt.show()
