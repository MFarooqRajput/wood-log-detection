# %%
cd ..
# Out:
# /Users/muhammadfarooq/Codebase/wood-log-detection/Pith2Bark

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scikitplot as skplt

import tensorflow as tf
from tensorflow.keras.preprocessing.image import load_img, img_to_array

from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout

from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split

from sklearn.metrics import accuracy_score
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %% [markdown]
# # Damage Dataset

# %%
def read_damage_min_max(damage_fname):
    df_damage = pd.read_csv(damage_fname)
    
    columns = ['min', 'max', 'mean', 'orig', 'diff_min_max', 'diff_orig_mean', 'damage_mean']
    df_damage_temp = df_damage.drop(columns=columns)
    df_damage_temp.rename(columns={'damage_min_max': 'Damage'}, inplace=True)

    df_damage_temp.reset_index(drop=True, inplace=True)

    return df_damage_temp

# %%
def read_damage_mean(damage_fname):
    df_damage = pd.read_csv(damage_fname)
    
    columns = ['min', 'max', 'mean', 'orig', 'diff_min_max', 'diff_orig_mean', 'damage_min_max']
    df_damage_temp = df_damage.drop(columns=columns)
    df_damage_temp.rename(columns={'damage_mean': 'Damage'}, inplace=True)

    df_damage_temp.reset_index(drop=True, inplace=True)

    return df_damage_temp

# %%
#damage
damage_url = "damage_dataset/damage.csv"

df_damage_min_max = read_damage_min_max(damage_url)

df_damage_mean = read_damage_mean(damage_url)

# %%
#STOP

# %%
df = df_damage_min_max

# %%
# set up the file paths for your image data and labels
img_size = (128, 128)

data_dir = 'damage_dataset/images'

# convert the DataFrame to a dictionary with specific column names as key and value
label_dict = {k: v for k, v in zip(df['image'], df['Damage'])}

# create empty lists to store the image data and labels
images = []
labels = []

# loop through each image file in the directory
for filename in os.listdir(data_dir):
    # load the image file and convert it to a NumPy array
    image = load_img(os.path.join(data_dir, filename), target_size=img_size)
    image = img_to_array(image)
    # preprocess the image by scaling the pixel values to be between 0 and 1
    image = image.astype('float32') / 255.0
    # add the preprocessed image and its label to the lists
    images.append(image)
    labels.append(label_dict[filename])

# convert the lists to NumPy arrays
images = np.array(images)
labels = np.array(labels)

# print the shape of the data to verify that it's been loaded correctly
print('Image data shape:', images.shape) #(148, 64, 64, 3)
print('Label data shape:', labels.shape) #(148,)
# Out:
# Image data shape: (148, 128, 128, 3)
# Label data shape: (148,)

# %%
#STOP

# %% [markdown]
# # Config

# %%
training_percent = 0.9

epochs, batch_size = 50, 32
kf = KFold(n_splits=3, shuffle=True, random_state=42)

early_stopping = tf.keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=10,
        restore_best_weights=True,
    )

METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'), 
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
    tf.keras.metrics.AUC(name='prc', curve='PR'), # precision-recall curve
]

# %%
def heat_map_normalized(y_true, y_pred):
    
    class_names = ['Not Damage', 'Damaged']
    
    skplt.metrics.plot_confusion_matrix(y_true, y_pred,
                                        figsize=(4,3),
                                        normalize=True)
    
    # Customize axis tick labels
    plt.xticks([0,1], class_names)
    plt.yticks([0,1], class_names)
    
    plt.yticks(rotation=90)
    
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()

# %%
def heat_map(_cm):
    # plot confusion matrix as heatmap
    labels = ['Not Damage', 'Damaged']
    
    # Set up the matplotlib figure
    plt.figure(figsize=(4, 3))
    
    # Generate a custom diverging colormap
    cmap = sns.diverging_palette(230, 20, as_cmap=True)
    
    sns.heatmap(_cm, annot=True, cmap=cmap, xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted labels')
    plt.ylabel('True labels')
    plt.show()

# %%
#STOP

# %% [markdown]
# # Model

# %%
class Baseline():
    def __init__(self, _input_dim, metrics=METRICS):
        # Define the model architecture
        model = Sequential()
        
        # convolutional layer
        model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=_input_dim))
        model.add(MaxPooling2D(pool_size=(2, 2)))
        model.add(Dropout(0.2))
                  
        # flatten output of conv
        model.add(Flatten())
                  
        # hidden layer
        model.add(Dense(64, activation='relu'))
        model.add(Dropout(0.2))
        
        # output layer         
        model.add(Dense(1, activation='sigmoid'))

        # Compile the model
        model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=metrics)

        self.model = model

    def train(self, X_train, y_train, X_val, y_val, epochs, batch_size):
        history = self.model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, batch_size=batch_size, callbacks=[early_stopping], verbose=2)
        return history
    
    def evaluate(self, X_test, y_test):
        results = self.model.evaluate(X_test, y_test, verbose=0)
        return results

    def predict(self, X_test):
        predictions = self.model.predict(X_test)
        return predictions

    def summary(self):
        self.model.summary()
        
    def metrics_names(self):
        return self.model.metrics_names

# %% [markdown]
# # Prepare dataset

# %%
X = images
y = labels

# split the data into a holdout set and the rest for K-Fold cross-validation
X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, train_size=training_percent, random_state=42)

# %%
input_dim = X_train.shape[1:]

model = Baseline(input_dim)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  dropout (Dropout)           (None, 63, 63, 32)        0
#
#  flatten (Flatten)           (None, 127008)            0
#
#  dense (Dense)               (None, 64)                8128576
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 8,129,537
# Trainable params: 8,129,537
# Non-trainable params: 0
# _________________________________________________________________

# %%
results = []

for train_index, val_index in kf.split(X_train):
    # split the dataset into training and validation sets for this fold
    X_train_kf, X_val_kf = X_train[train_index], X_train[val_index]
    y_train_kf, y_val_kf = y_train[train_index], y_train[val_index]
    
    model = Baseline(input_dim)
    
    history = model.train(X_train_kf, y_train_kf, X_val_kf, y_val_kf, epochs, batch_size)
    plt.plot(history.history['loss'])
    plt.show()
    
    results_m = model.evaluate(X_val_kf, y_val_kf)
    
    for name, value in zip(model.metrics_names(), results_m):
        print(name, ': ', value)
        if name == 'accuracy':
            accuracy_kf = value
            results.append(accuracy_kf)
            print(f"Accuracy on validation set: {accuracy_kf:.2f}")
    
# Calculate the average accuracy score for the K-fold cross-validation
print("results",results)
print(f"K-fold cross-validation accuracy: {sum(results) / len(results):.2f}")

y_pred_holdout = model.predict(X_holdout)
accuracy_holdout = accuracy_score(np.round(y_holdout), np.round(y_pred_holdout))
print(f"Accuracy on holdout set: {accuracy_holdout:.2f}")

balanced_accuracy_holdout = balanced_accuracy_score(np.round(y_holdout), np.round(y_pred_holdout))
print(f"Balanced Accuracy on holdout set: {balanced_accuracy_holdout:.2f}")

print("\nClassification Report:\n")
print(classification_report(np.round(y_holdout), np.round(y_pred_holdout), digits = 3))

cm = confusion_matrix(np.round(y_holdout), np.round(y_pred_holdout))
heat_map(cm)
TN, FP, FN, TP = confusion_matrix(np.round(y_holdout), np.round(y_pred_holdout)).ravel()
print('True Positive(TP)  = ', TP)
print('False Positive(FP) = ', FP)
print('True Negative(TN)  = ', TN)
print('False Negative(FN) = ', FN)

accuracy =  (TP + TN) / (TP + FP + TN + FN)
print('Accuracy of the binary classifier = {:0.3f}'.format(accuracy))

heat_map_normalized(np.round(y_holdout), np.round(y_pred_holdout))
# Out:
# Epoch 1/50
# 3/3 - 3s - loss: 0.8107 - tp: 17.0000 - fp: 25.0000 - tn: 30.0000 - fn: 16.0000 - accuracy: 0.5341 - precision: 0.4048 - recall: 0.5152 - auc: 0.5408 - prc: 0.5329 - val_loss: 0.6736 - val_tp: 15.0000 - val_fp: 26.0000 - val_tn: 3.0000 - val_fn: 1.0000 - val_accuracy: 0.4000 - val_precision: 0.3659 - val_recall: 0.9375 - val_auc: 0.7877 - val_prc: 0.8045 - 3s/epoch - 853ms/step
# Epoch 2/50
# 3/3 - 1s - loss: 0.5453 - tp: 28.0000 - fp: 19.0000 - tn: 36.0000 - fn: 5.0000 - accuracy: 0.7273 - precision: 0.5957 - recall: 0.8485 - auc: 0.8399 - prc: 0.7855 - val_loss: 0.4044 - val_tp: 10.0000 - val_fp: 0.0000e+00 - val_tn: 29.0000 - val_fn: 6.0000 - val_accuracy: 0.8667 - val_precision: 1.0000 - val_recall: 0.6250 - val_auc: 0.8093 - val_prc: 0.8102 - 542ms/epoch - 181ms/step
# Epoch 3/50
# 3/3 - 1s - loss: 0.4484 - tp: 21.0000 - fp: 1.0000 - tn: 54.0000 - fn: 12.0000 - accuracy: 0.8523 - precision: 0.9545 - recall: 0.6364 - auc: 0.8094 - prc: 0.8046 - val_loss: 0.4150 - val_tp: 10.0000 - val_fp: 0.0000e+00 - val_tn: 29.0000 - val_fn: 6.0000 - val_accuracy: 0.8667 - val_precision: 1.0000 - val_recall: 0.6250 - val_auc: 0.8114 - val_prc: 0.8085 - 531ms/epoch - 177ms/step
# Epoch 4/50
# 3/3 - 1s - loss: 0.4254 - tp: 21.0000 - fp: 1.0000 - tn: 54.0000 - fn: 12.0000 - accuracy: 0.8523 - precision: 0.9545 - recall: 0.6364 - auc: 0.8116 - prc: 0.8381 - val_loss: 0.4690 - val_tp: 10.0000 - val_fp: 5.0000 - val_tn: 24.0000 - val_fn: 6.0000 - val_accuracy: 0.7556 - val_precision: 0.6667 - val_recall: 0.6250 - val_auc: 0.8125 - val_prc: 0.8140 - 564ms/epoch - 188ms/step
# Epoch 5/50
# 3/3 - 1s - loss: 0.3775 - tp: 24.0000 - fp: 4.0000 - tn: 51.0000 - fn: 9.0000 - accuracy: 0.8523 - precision: 0.8571 - recall: 0.7273 - auc: 0.8573 - prc: 0.8690 - val_loss: 0.5415 - val_tp: 10.0000 - val_fp: 5.0000 - val_tn: 24.0000 - val_fn: 6.0000 - val_accuracy: 0.7556 - val_precision: 0.6667 - val_recall: 0.6250 - val_auc: 0.8103 - val_prc: 0.8127 - 542ms/epoch - 181ms/step
# Epoch 6/50
# 3/3 - 1s - loss: 0.4448 - tp: 24.0000 - fp: 4.0000 - tn: 51.0000 - fn: 9.0000 - accuracy: 0.8523 - precision: 0.8571 - recall: 0.7273 - auc: 0.8256 - prc: 0.8462 - val_loss: 0.4877 - val_tp: 10.0000 - val_fp: 5.0000 - val_tn: 24.0000 - val_fn: 6.0000 - val_accuracy: 0.7556 - val_precision: 0.6667 - val_recall: 0.6250 - val_auc: 0.8125 - val_prc: 0.8133 - 572ms/epoch - 191ms/step
# Epoch 7/50
# 3/3 - 1s - loss: 0.3676 - tp: 24.0000 - fp: 2.0000 - tn: 53.0000 - fn: 9.0000 - accuracy: 0.8750 - precision: 0.9231 - recall: 0.7273 - auc: 0.8410 - prc: 0.8644 - val_loss: 0.4512 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 26.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7692 - val_recall: 0.6250 - val_auc: 0.8103 - val_prc: 0.8117 - 524ms/epoch - 175ms/step
# Epoch 8/50
# 3/3 - 1s - loss: 0.4209 - tp: 23.0000 - fp: 1.0000 - tn: 54.0000 - fn: 10.0000 - accuracy: 0.8750 - precision: 0.9583 - recall: 0.6970 - auc: 0.8107 - prc: 0.8229 - val_loss: 0.4391 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 26.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7692 - val_recall: 0.6250 - val_auc: 0.8103 - val_prc: 0.8121 - 591ms/epoch - 197ms/step
# Epoch 9/50
# 3/3 - 1s - loss: 0.3720 - tp: 24.0000 - fp: 2.0000 - tn: 53.0000 - fn: 9.0000 - accuracy: 0.8750 - precision: 0.9231 - recall: 0.7273 - auc: 0.8713 - prc: 0.8449 - val_loss: 0.4376 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 26.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7692 - val_recall: 0.6250 - val_auc: 0.8125 - val_prc: 0.8147 - 629ms/epoch - 210ms/step
# Epoch 10/50
# 3/3 - 1s - loss: 0.3538 - tp: 24.0000 - fp: 3.0000 - tn: 52.0000 - fn: 9.0000 - accuracy: 0.8636 - precision: 0.8889 - recall: 0.7273 - auc: 0.9008 - prc: 0.8905 - val_loss: 0.4229 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 26.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7692 - val_recall: 0.6250 - val_auc: 0.8147 - val_prc: 0.8143 - 612ms/epoch - 204ms/step
# Epoch 11/50
# 3/3 - 1s - loss: 0.3459 - tp: 24.0000 - fp: 1.0000 - tn: 54.0000 - fn: 9.0000 - accuracy: 0.8864 - precision: 0.9600 - recall: 0.7273 - auc: 0.8725 - prc: 0.8809 - val_loss: 0.4178 - val_tp: 10.0000 - val_fp: 3.0000 - val_tn: 26.0000 - val_fn: 6.0000 - val_accuracy: 0.8000 - val_precision: 0.7692 - val_recall: 0.6250 - val_auc: 0.8147 - val_prc: 0.8157 - 580ms/epoch - 193ms/step
# Epoch 12/50
# 3/3 - 1s - loss: 0.3340 - tp: 24.0000 - fp: 1.0000 - tn: 54.0000 - fn: 9.0000 - accuracy: 0.8864 - precision: 0.9600 - recall: 0.7273 - auc: 0.9154 - prc: 0.9091 - val_loss: 0.4093 - val_tp: 10.0000 - val_fp: 2.0000 - val_tn: 27.0000 - val_fn: 6.0000 - val_accuracy: 0.8222 - val_precision: 0.8333 - val_recall: 0.6250 - val_auc: 0.8136 - val_prc: 0.8154 - 559ms/epoch - 186ms/step
# loss :  0.4044479429721832
# tp :  10.0
# fp :  0.0
# tn :  29.0
# fn :  6.0
# accuracy :  0.8666666746139526
# Accuracy on validation set: 0.87
# precision :  1.0
# recall :  0.625
# auc :  0.8092671632766724
# prc :  0.8101726174354553
# Epoch 1/50
# 3/3 - 3s - loss: 0.5506 - tp: 26.0000 - fp: 17.0000 - tn: 74.0000 - fn: 17.0000 - accuracy: 0.7463 - precision: 0.6047 - recall: 0.6047 - auc: 0.7754 - prc: 0.7143 - val_loss: 0.6114 - val_tp: 13.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 9.0000 - val_accuracy: 0.7727 - val_precision: 0.9286 - val_recall: 0.5909 - val_auc: 0.7469 - val_prc: 0.7343 - 3s/epoch - 833ms/step
# Epoch 2/50
# 3/3 - 1s - loss: 0.3604 - tp: 17.0000 - fp: 1.0000 - tn: 61.0000 - fn: 10.0000 - accuracy: 0.8764 - precision: 0.9444 - recall: 0.6296 - auc: 0.8542 - prc: 0.8169 - val_loss: 0.6002 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7686 - val_prc: 0.8184 - 596ms/epoch - 199ms/step
# Epoch 3/50
# 3/3 - 1s - loss: 0.4578 - tp: 18.0000 - fp: 4.0000 - tn: 58.0000 - fn: 9.0000 - accuracy: 0.8539 - precision: 0.8182 - recall: 0.6667 - auc: 0.7885 - prc: 0.7891 - val_loss: 0.7985 - val_tp: 14.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 8.0000 - val_accuracy: 0.7955 - val_precision: 0.9333 - val_recall: 0.6364 - val_auc: 0.7335 - val_prc: 0.7844 - 555ms/epoch - 185ms/step
# Epoch 4/50
# 3/3 - 1s - loss: 0.3657 - tp: 17.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 10.0000 - accuracy: 0.8876 - precision: 1.0000 - recall: 0.6296 - auc: 0.8501 - prc: 0.8361 - val_loss: 0.6628 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7521 - val_prc: 0.8094 - 558ms/epoch - 186ms/step
# Epoch 5/50
# 3/3 - 1s - loss: 0.3465 - tp: 18.0000 - fp: 1.0000 - tn: 61.0000 - fn: 9.0000 - accuracy: 0.8876 - precision: 0.9474 - recall: 0.6667 - auc: 0.8507 - prc: 0.8254 - val_loss: 0.6280 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7645 - val_prc: 0.8157 - 588ms/epoch - 196ms/step
# Epoch 6/50
# 3/3 - 1s - loss: 0.3379 - tp: 17.0000 - fp: 3.0000 - tn: 59.0000 - fn: 10.0000 - accuracy: 0.8539 - precision: 0.8500 - recall: 0.6296 - auc: 0.8602 - prc: 0.8388 - val_loss: 0.7584 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7107 - val_prc: 0.7665 - 569ms/epoch - 190ms/step
# Epoch 7/50
# 3/3 - 1s - loss: 0.3453 - tp: 17.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 10.0000 - accuracy: 0.8876 - precision: 1.0000 - recall: 0.6296 - auc: 0.8865 - prc: 0.8703 - val_loss: 0.6775 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7159 - val_prc: 0.7815 - 564ms/epoch - 188ms/step
# Epoch 8/50
# 3/3 - 1s - loss: 0.2537 - tp: 18.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 9.0000 - accuracy: 0.8989 - precision: 1.0000 - recall: 0.6667 - auc: 0.9358 - prc: 0.9206 - val_loss: 0.5973 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7366 - val_prc: 0.7992 - 579ms/epoch - 193ms/step
# Epoch 9/50
# 3/3 - 1s - loss: 0.2788 - tp: 21.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 6.0000 - accuracy: 0.9326 - precision: 1.0000 - recall: 0.7778 - auc: 0.9636 - prc: 0.9375 - val_loss: 0.6035 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7500 - val_prc: 0.8072 - 567ms/epoch - 189ms/step
# Epoch 10/50
# 3/3 - 1s - loss: 0.3010 - tp: 18.0000 - fp: 1.0000 - tn: 61.0000 - fn: 9.0000 - accuracy: 0.8876 - precision: 0.9474 - recall: 0.6667 - auc: 0.9158 - prc: 0.8788 - val_loss: 0.6691 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7211 - val_prc: 0.7831 - 556ms/epoch - 185ms/step
# Epoch 11/50
# 3/3 - 1s - loss: 0.2777 - tp: 17.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 10.0000 - accuracy: 0.8876 - precision: 1.0000 - recall: 0.6296 - auc: 0.9361 - prc: 0.9020 - val_loss: 0.7016 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7262 - val_prc: 0.7851 - 566ms/epoch - 189ms/step
# Epoch 12/50
# 3/3 - 1s - loss: 0.2355 - tp: 17.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 10.0000 - accuracy: 0.8876 - precision: 1.0000 - recall: 0.6296 - auc: 0.9707 - prc: 0.9383 - val_loss: 0.6364 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7603 - val_prc: 0.8107 - 585ms/epoch - 195ms/step
# Epoch 13/50
# 3/3 - 1s - loss: 0.2335 - tp: 19.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 8.0000 - accuracy: 0.9101 - precision: 1.0000 - recall: 0.7037 - auc: 0.9740 - prc: 0.9555 - val_loss: 0.6402 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7634 - val_prc: 0.8122 - 583ms/epoch - 194ms/step
# Epoch 14/50
# 3/3 - 1s - loss: 0.2165 - tp: 18.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 9.0000 - accuracy: 0.8989 - precision: 1.0000 - recall: 0.6667 - auc: 0.9761 - prc: 0.9535 - val_loss: 0.6882 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7231 - val_prc: 0.7865 - 600ms/epoch - 200ms/step
# Epoch 15/50
# 3/3 - 1s - loss: 0.2099 - tp: 18.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 9.0000 - accuracy: 0.8989 - precision: 1.0000 - recall: 0.6667 - auc: 0.9904 - prc: 0.9807 - val_loss: 0.6706 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7448 - val_prc: 0.7999 - 631ms/epoch - 210ms/step
# Epoch 16/50
# 3/3 - 1s - loss: 0.1987 - tp: 19.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 8.0000 - accuracy: 0.9101 - precision: 1.0000 - recall: 0.7037 - auc: 0.9982 - prc: 0.9960 - val_loss: 0.6500 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7665 - val_prc: 0.8122 - 613ms/epoch - 204ms/step
# Epoch 17/50
# 3/3 - 1s - loss: 0.1914 - tp: 18.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 9.0000 - accuracy: 0.8989 - precision: 1.0000 - recall: 0.6667 - auc: 0.9937 - prc: 0.9875 - val_loss: 0.6831 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7490 - val_prc: 0.8039 - 681ms/epoch - 227ms/step
# Epoch 18/50
# 3/3 - 1s - loss: 0.1909 - tp: 18.0000 - fp: 0.0000e+00 - tn: 62.0000 - fn: 9.0000 - accuracy: 0.8989 - precision: 1.0000 - recall: 0.6667 - auc: 0.9961 - prc: 0.9913 - val_loss: 0.6991 - val_tp: 15.0000 - val_fp: 1.0000 - val_tn: 21.0000 - val_fn: 7.0000 - val_accuracy: 0.8182 - val_precision: 0.9375 - val_recall: 0.6818 - val_auc: 0.7479 - val_prc: 0.8037 - 790ms/epoch - 263ms/step
# loss :  0.5973337888717651
# tp :  15.0
# fp :  1.0
# tn :  21.0
# fn :  7.0
# accuracy :  0.8181818127632141
# Accuracy on validation set: 0.82
# precision :  0.9375
# recall :  0.6818181872367859
# auc :  0.7365702390670776
# prc :  0.7992426753044128
# Epoch 1/50
# 3/3 - 3s - loss: 0.6176 - tp: 37.0000 - fp: 17.0000 - tn: 56.0000 - fn: 23.0000 - accuracy: 0.6992 - precision: 0.6852 - recall: 0.6167 - auc: 0.7461 - prc: 0.7703 - val_loss: 0.5102 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 30.0000 - val_fn: 3.0000 - val_accuracy: 0.8636 - val_precision: 0.7273 - val_recall: 0.7273 - val_auc: 0.8581 - val_prc: 0.8475 - 3s/epoch - 1s/step
# Epoch 2/50
# 3/3 - 1s - loss: 0.5649 - tp: 23.0000 - fp: 5.0000 - tn: 46.0000 - fn: 15.0000 - accuracy: 0.7753 - precision: 0.8214 - recall: 0.6053 - auc: 0.8029 - prc: 0.7782 - val_loss: 0.3024 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.8444 - val_prc: 0.8237 - 559ms/epoch - 186ms/step
# Epoch 3/50
# 3/3 - 1s - loss: 0.4940 - tp: 24.0000 - fp: 1.0000 - tn: 50.0000 - fn: 14.0000 - accuracy: 0.8315 - precision: 0.9600 - recall: 0.6316 - auc: 0.8137 - prc: 0.8400 - val_loss: 0.3585 - val_tp: 8.0000 - val_fp: 3.0000 - val_tn: 30.0000 - val_fn: 3.0000 - val_accuracy: 0.8636 - val_precision: 0.7273 - val_recall: 0.7273 - val_auc: 0.8623 - val_prc: 0.8464 - 555ms/epoch - 185ms/step
# Epoch 4/50
# 3/3 - 1s - loss: 0.4425 - tp: 25.0000 - fp: 5.0000 - tn: 46.0000 - fn: 13.0000 - accuracy: 0.7978 - precision: 0.8333 - recall: 0.6579 - auc: 0.8715 - prc: 0.8347 - val_loss: 0.3665 - val_tp: 8.0000 - val_fp: 2.0000 - val_tn: 31.0000 - val_fn: 3.0000 - val_accuracy: 0.8864 - val_precision: 0.8000 - val_recall: 0.7273 - val_auc: 0.8705 - val_prc: 0.8370 - 543ms/epoch - 181ms/step
# Epoch 5/50
# 3/3 - 1s - loss: 0.4190 - tp: 25.0000 - fp: 3.0000 - tn: 48.0000 - fn: 13.0000 - accuracy: 0.8202 - precision: 0.8929 - recall: 0.6579 - auc: 0.8372 - prc: 0.8576 - val_loss: 0.3433 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.8017 - val_prc: 0.7970 - 536ms/epoch - 179ms/step
# Epoch 6/50
# 3/3 - 1s - loss: 0.4012 - tp: 24.0000 - fp: 1.0000 - tn: 50.0000 - fn: 14.0000 - accuracy: 0.8315 - precision: 0.9600 - recall: 0.6316 - auc: 0.8780 - prc: 0.8751 - val_loss: 0.3448 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.7989 - val_prc: 0.7959 - 549ms/epoch - 183ms/step
# Epoch 7/50
# 3/3 - 1s - loss: 0.3729 - tp: 24.0000 - fp: 1.0000 - tn: 50.0000 - fn: 14.0000 - accuracy: 0.8315 - precision: 0.9600 - recall: 0.6316 - auc: 0.9195 - prc: 0.9170 - val_loss: 0.3430 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.7989 - val_prc: 0.7960 - 553ms/epoch - 184ms/step
# Epoch 8/50
# 3/3 - 1s - loss: 0.3666 - tp: 25.0000 - fp: 1.0000 - tn: 50.0000 - fn: 13.0000 - accuracy: 0.8427 - precision: 0.9615 - recall: 0.6579 - auc: 0.9505 - prc: 0.9400 - val_loss: 0.3670 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.8127 - val_prc: 0.7981 - 535ms/epoch - 178ms/step
# Epoch 9/50
# 3/3 - 1s - loss: 0.3677 - tp: 26.0000 - fp: 1.0000 - tn: 50.0000 - fn: 12.0000 - accuracy: 0.8539 - precision: 0.9630 - recall: 0.6842 - auc: 0.9350 - prc: 0.9315 - val_loss: 0.3482 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.8072 - val_prc: 0.7923 - 545ms/epoch - 182ms/step
# Epoch 10/50
# 3/3 - 1s - loss: 0.3128 - tp: 26.0000 - fp: 1.0000 - tn: 50.0000 - fn: 12.0000 - accuracy: 0.8539 - precision: 0.9630 - recall: 0.6842 - auc: 0.9696 - prc: 0.9634 - val_loss: 0.3184 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.7755 - val_prc: 0.7882 - 530ms/epoch - 177ms/step
# Epoch 11/50
# 3/3 - 1s - loss: 0.3390 - tp: 25.0000 - fp: 1.0000 - tn: 50.0000 - fn: 13.0000 - accuracy: 0.8427 - precision: 0.9615 - recall: 0.6579 - auc: 0.9329 - prc: 0.9340 - val_loss: 0.3295 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.7837 - val_prc: 0.7909 - 543ms/epoch - 181ms/step
# Epoch 12/50
# 3/3 - 1s - loss: 0.3118 - tp: 25.0000 - fp: 1.0000 - tn: 50.0000 - fn: 13.0000 - accuracy: 0.8427 - precision: 0.9615 - recall: 0.6579 - auc: 0.9649 - prc: 0.9628 - val_loss: 0.3333 - val_tp: 7.0000 - val_fp: 0.0000e+00 - val_tn: 33.0000 - val_fn: 4.0000 - val_accuracy: 0.9091 - val_precision: 1.0000 - val_recall: 0.6364 - val_auc: 0.7741 - val_prc: 0.7880 - 536ms/epoch - 179ms/step
# loss :  0.30235713720321655
# tp :  7.0
# fp :  0.0
# tn :  33.0
# fn :  4.0
# accuracy :  0.9090909361839294
# Accuracy on validation set: 0.91
# precision :  1.0
# recall :  0.6363636255264282
# auc :  0.8443526029586792
# prc :  0.8236821889877319
# results [0.8666666746139526, 0.8181818127632141, 0.9090909361839294]
# K-fold cross-validation accuracy: 0.86
# 1/1 [==============================] - 0s 95ms/step
# Accuracy on holdout set: 0.93
# Balanced Accuracy on holdout set: 0.90
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0      0.909     1.000     0.952        10
#            1      1.000     0.800     0.889         5
#
#     accuracy                          0.933        15
#    macro avg      0.955     0.900     0.921        15
# weighted avg      0.939     0.933     0.931        15
# True Positive(TP)  =  4
# False Positive(FP) =  0
# True Negative(TN)  =  10
# False Negative(FN) =  1
# Accuracy of the binary classifier = 0.933

# %%
# Calculate performance metrics
accuracy = accuracy_score(np.round(y_holdout), np.round(y_pred_holdout)) * 100
balanced_accuracy = balanced_accuracy_score(np.round(y_holdout), np.round(y_pred_holdout)) * 100
auc = roc_auc_score(np.round(y_holdout), np.round(y_pred_holdout))
precision = precision_score(np.round(y_holdout), np.round(y_pred_holdout))
recall = recall_score(np.round(y_holdout), np.round(y_pred_holdout))
f1 = f1_score(np.round(y_holdout), np.round(y_pred_holdout))

# Print results
print(f"Accuracy: {accuracy:.2f}%")
print(f"Balanced Accuracy: {balanced_accuracy:.2f}%")
print(f"AUC: {auc:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 score: {f1:.2f}")
# Out:
# Accuracy: 93.33%
# Balanced Accuracy: 90.00%
# AUC: 0.90
# Precision: 1.00
# Recall: 0.80
# F1 score: 0.89

# %%
#STOP
