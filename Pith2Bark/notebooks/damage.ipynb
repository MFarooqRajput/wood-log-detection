# %%
cd ..
# Out:
# /Users/muhammadfarooq/Codebase/thesis-experiment/Pith2Bark

# %%
from src.winner import winner_model_rings
from src.damage import damage
from src.damage import merge_df
from src.damage import save_damage

# %%
mse_url = "output/ringsranking_mse_sixteen.csv"
rings_url = "output/ringsranking_rings_sixteen.csv"
df_ringsranking_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_ringsranking_sixteen = damage(df_ringsranking_sixteen)
df_damage_ringsranking_sixteen
# Out:
# Polar Pith Canny(blur otsu) 12.829318845239923 (subseq)
#                                                                          image  \
# model
# Polar Pith Canny(blur otsu)  2-34e23370868237a073d086fb64851017e9b2c8c9_859...
# Polar Pith Canny(blur otsu)  1-5d205d5ea6bafd3c2e038cf1139cdd5a9825388f_275...
# Polar Pith Canny(blur otsu)  1-11c00bf7cc3e03dc86bde8a20c8ab390b0b2f2a4_d5d...
# Polar Pith Canny(blur otsu)  2-8c5de8aa63e57b1e5d3a11ce4c4e2ded042b2ef3_069...
# Polar Pith Canny(blur otsu)  1-3d78e56849a16c0b17831129f6059e367574a138_856...
# Polar Pith Canny(blur otsu)  1-947a57fc1b94be1fb8a5cce439cd8112016648b1_b15...
# Polar Pith Canny(blur otsu)  1-1f43f59e9f5ead12a13b1cd892a8757242367189_9cd...
# Polar Pith Canny(blur otsu)  1-85fde97a518625ed46589a6be46300e36c3ad0d9_662...
# Polar Pith Canny(blur otsu)  1-e50b5a99fd9bab50130099c750df6d80f50a9b4e_fda...
# Polar Pith Canny(blur otsu)  1-0d8eabdfed2cb1f0d455e5a2050d78ba39ae6cff_066...
# ...

# %%
mse_url = "output/ringsranking_mse_thirtytwo.csv"
rings_url = "output/ringsranking_rings_thirtytwo.csv"
df_ringsranking_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_ringsranking_thirtytwo = damage(df_ringsranking_thirtytwo)
df_damage_ringsranking_thirtytwo
# Out:
# Polar Pith Canny(blur otsu) 12.88055458721076 (subseq)
#                                                                          image  \
# model
# Polar Pith Canny(blur otsu)  2-34e23370868237a073d086fb64851017e9b2c8c9_859...
# Polar Pith Canny(blur otsu)  1-5d205d5ea6bafd3c2e038cf1139cdd5a9825388f_275...
# Polar Pith Canny(blur otsu)  1-11c00bf7cc3e03dc86bde8a20c8ab390b0b2f2a4_d5d...
# Polar Pith Canny(blur otsu)  2-8c5de8aa63e57b1e5d3a11ce4c4e2ded042b2ef3_069...
# Polar Pith Canny(blur otsu)  1-3d78e56849a16c0b17831129f6059e367574a138_856...
# Polar Pith Canny(blur otsu)  1-947a57fc1b94be1fb8a5cce439cd8112016648b1_b15...
# Polar Pith Canny(blur otsu)  1-1f43f59e9f5ead12a13b1cd892a8757242367189_9cd...
# Polar Pith Canny(blur otsu)  1-85fde97a518625ed46589a6be46300e36c3ad0d9_662...
# Polar Pith Canny(blur otsu)  1-e50b5a99fd9bab50130099c750df6d80f50a9b4e_fda...
# Polar Pith Canny(blur otsu)  1-0d8eabdfed2cb1f0d455e5a2050d78ba39ae6cff_066...
# ...

# %%
#STOP

# %%
mse_url = "output/pine_mse_sixteen.csv"
rings_url = "output/pine_rings_sixteen.csv"
df_pine_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_pine_sixteen = damage(df_pine_sixteen)
df_damage_pine_sixteen
# Out:
# Polar Pith Canny(blur triangle) 19.888455438324574 (peaks)
#                                     image  min  max      mean   orig  \
# model
# Polar Pith Canny(blur triangle)  6689.jpg   54  123   91.6250  113.8
# Polar Pith Canny(blur triangle)  6683.jpg   65  148   89.6250  106.2
# Polar Pith Canny(blur triangle)  6721.jpg   66  154  109.1250   80.6
# Polar Pith Canny(blur triangle)  6723.jpg   53  120   78.8750   65.2
# Polar Pith Canny(blur triangle)  6722.jpg   51  126   85.7500   93.4
# Polar Pith Canny(blur triangle)  6690.jpg   64  103   83.1250  104.2
# Polar Pith Canny(blur triangle)  6725.jpg   65  127   94.2500   83.2
# Polar Pith Canny(blur triangle)  6724.jpg   54  123   84.3125   73.4
# Polar Pith Canny(blur triangle)  6693.jpg   49  104   76.8125  109.2
#
#                                  diff_min_max  diff_orig_mean  damage_min_max  \
# model
# Polar Pith Canny(blur triangle)            69         22.1750               1
# ...

# %%
mse_url = "output/pine_mse_thirtytwo.csv"
rings_url = "output/pine_rings_thirtytwo.csv"
df_pine_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_pine_thirtytwo = damage(df_pine_thirtytwo)
df_damage_pine_thirtytwo
# Out:
# Polar Pith Canny(blur triangle) 19.591747084408897 (peaks)
#                                     image  min  max       mean   orig  \
# model
# Polar Pith Canny(blur triangle)  6689.jpg   58  145   90.81250  113.8
# Polar Pith Canny(blur triangle)  6683.jpg   66  148   88.46875  106.2
# Polar Pith Canny(blur triangle)  6721.jpg   60  154  110.40625   80.6
# Polar Pith Canny(blur triangle)  6723.jpg   54  127   79.96875   65.2
# Polar Pith Canny(blur triangle)  6722.jpg   48  150   91.00000   93.4
# Polar Pith Canny(blur triangle)  6690.jpg   59  110   86.40625  104.2
# Polar Pith Canny(blur triangle)  6725.jpg   60  127   93.71875   83.2
# Polar Pith Canny(blur triangle)  6724.jpg   54  123   83.90625   73.4
# Polar Pith Canny(blur triangle)  6693.jpg   48  111   78.18750  109.2
#
#                                  diff_min_max  diff_orig_mean  damage_min_max  \
# model
# Polar Pith Canny(blur triangle)            87        22.98750               1
# ...

# %%
#STOP

# %%
mse_url = "output/fur_mse_sixteen.csv"
rings_url = "output/fur_rings_sixteen.csv"
df_fur_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_fur_sixteen = damage(df_fur_sixteen)
df_damage_fur_sixteen
# Out:
# Polar Pith Canny(blur triangle) 13.428984012468806 (peaks)
#                                     image  min  max     mean  orig  \
# model
# Polar Pith Canny(blur triangle)  6702.jpg   53  110  80.8750  73.2
# Polar Pith Canny(blur triangle)  6703.jpg   37   88  67.1250  75.6
# Polar Pith Canny(blur triangle)  6699.jpg   49  108  71.8750  82.2
# Polar Pith Canny(blur triangle)  6705.jpg   74  135  95.3750  67.4
# Polar Pith Canny(blur triangle)  6709.jpg   49  120  76.6250  72.0
# Polar Pith Canny(blur triangle)  6696.jpg   37  119  70.5000  65.0
# Polar Pith Canny(blur triangle)  6695.jpg   51  113  80.8125  67.0
#
#                                  diff_min_max  diff_orig_mean  damage_min_max  \
# model
# Polar Pith Canny(blur triangle)            57          7.6750               1
# Polar Pith Canny(blur triangle)            51          8.4750               1
# Polar Pith Canny(blur triangle)            59         10.3250               1
# ...

# %%
mse_url = "output/fur_mse_thirtytwo.csv"
rings_url = "output/fur_rings_thirtytwo.csv"
df_fur_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_fur_thirtytwo = damage(df_fur_thirtytwo)
df_damage_fur_thirtytwo
# Out:
# Polar Pith Canny(blur triangle) 13.688767879960144 (peaks)
#                                     image  min  max      mean  orig  \
# model
# Polar Pith Canny(blur triangle)  6702.jpg   47  109  80.12500  73.2
# Polar Pith Canny(blur triangle)  6703.jpg   37  103  70.81250  75.6
# Polar Pith Canny(blur triangle)  6699.jpg   46  110  72.12500  82.2
# Polar Pith Canny(blur triangle)  6705.jpg   71  135  95.78125  67.4
# Polar Pith Canny(blur triangle)  6709.jpg   49  116  75.71875  72.0
# Polar Pith Canny(blur triangle)  6696.jpg   36  119  70.46875  65.0
# Polar Pith Canny(blur triangle)  6695.jpg   51  123  84.03125  67.0
#
#                                  diff_min_max  diff_orig_mean  damage_min_max  \
# model
# Polar Pith Canny(blur triangle)            62         6.92500               1
# Polar Pith Canny(blur triangle)            66         4.78750               1
# Polar Pith Canny(blur triangle)            64        10.07500               1
# ...

# %%
#STOP

# %%
mse_url = "output/tracy_mse_sixteen.csv"
rings_url = "output/tracy_rings_sixteen.csv"
df_tracy_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_tracy_sixteen = damage(df_tracy_sixteen)
df_damage_tracy_sixteen
# Out:
# Polar Canny(triangle) 39.683736416974455 (peaks)
#                           image  min  max      mean   orig  diff_min_max  \
# model
# Polar Canny(triangle)  6701.jpg   87  155  110.0625   94.0            68
# Polar Canny(triangle)  6728.jpg   34  136   91.5000   97.2           102
# Polar Canny(triangle)  6700.jpg   88  138  113.6250  101.2            50
# Polar Canny(triangle)  6717.jpg   82  152  116.3750   73.2            70
# Polar Canny(triangle)  6688.jpg   84  141  114.5000  119.0            57
# Polar Canny(triangle)  6698.jpg   89  162  117.9375   73.2            73
# Polar Canny(triangle)  6707.jpg   76  136  114.8750   77.2            60
# Polar Canny(triangle)  6713.jpg   83  159  112.7500   83.2            76
# Polar Canny(triangle)  6710.jpg   90  152  105.8750   81.2            62
# Polar Canny(triangle)  6711.jpg   35  129  104.7500   83.0            94
# Polar Canny(triangle)  6697.jpg    9  141   89.5625   85.0           132
# ...

# %%
mse_url = "output/tracy_mse_thirtytwo.csv"
rings_url = "output/tracy_rings_thirtytwo.csv"
df_tracy_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_tracy_thirtytwo = damage(df_tracy_thirtytwo)
df_damage_tracy_thirtytwo
# Out:
# Polar Pith Canny(triangle) 39.48914666858598 (peaks)
#                                image  min  max       mean   orig  \
# model
# Polar Pith Canny(triangle)  6701.jpg   79  155  122.43750   94.0
# Polar Pith Canny(triangle)  6728.jpg   51  165   94.71875   97.2
# Polar Pith Canny(triangle)  6700.jpg   74  153  114.53125  101.2
# Polar Pith Canny(triangle)  6717.jpg   69  143  110.90625   73.2
# Polar Pith Canny(triangle)  6688.jpg   77  140  112.81250  119.0
# Polar Pith Canny(triangle)  6698.jpg   85  156  120.46875   73.2
# Polar Pith Canny(triangle)  6707.jpg   77  163  123.21875   77.2
# Polar Pith Canny(triangle)  6713.jpg   67  133   97.46875   83.2
# Polar Pith Canny(triangle)  6710.jpg   80  137  106.59375   81.2
# Polar Pith Canny(triangle)  6711.jpg   55  136   92.90625   83.0
# Polar Pith Canny(triangle)  6697.jpg   56  150   96.03125   85.0
# Polar Pith Canny(triangle)  6720.jpg   67  144  100.25000   59.2
# ...

# %%
#STOP

# %%
mse_url = "output/data_mse_sixteen.csv"
rings_url = "output/data_rings_sixteen.csv"
df_data_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_data_sixteen = damage(df_data_sixteen)
df_damage_data_sixteen
# Out:
# Canny(triangle) 18.789996216404624 (subseq)
#                                                     image  min  max     mean  \
# model
# Canny(triangle)  0f82cbda-4f09-42cb-8a2e-6862a5a8561a.jpg   42   75  56.2500
# Canny(triangle)  ded672c3-1e54-4514-97ea-ef2ca3d4ffe6.jpg   30   55  43.3125
# Canny(triangle)  0ed6b6c7-fc8e-49a1-b077-7bddd2ee202f.jpg   30   48  38.8750
# Canny(triangle)  0e4c7385-c750-4cf6-9bfb-2818544b0d1d.jpg   53   87  68.1250
# Canny(triangle)  46c88d82-d909-4156-b198-79fd0571a983.jpg   26   47  36.0625
# ...                                                   ...  ...  ...      ...
# Canny(triangle)  f5744022-17de-4885-b35c-5f94b9c2a586.jpg   42   65  50.1250
# Canny(triangle)  f5382313-d332-471d-a5d1-629bb8e2e903.jpg   30   65  43.0625
# Canny(triangle)  0da44e1b-8158-40d4-a311-2fc016111d13.jpg   31   65  42.4375
# Canny(triangle)  0da46961-93dc-492c-b4d8-54d9b7e439fa.jpg   39   57  48.7500
# ...

# %%
mse_url = "output/data_mse_thirtytwo.csv"
rings_url = "output/data_rings_thirtytwo.csv"
df_data_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_data_thirtytwo = damage(df_data_thirtytwo)
df_damage_data_thirtytwo
# Out:
# Canny(triangle) 18.871624925897343 (subseq)
#                                                     image  min  max      mean  \
# model
# Canny(triangle)  0f82cbda-4f09-42cb-8a2e-6862a5a8561a.jpg   39   76  58.15625
# Canny(triangle)  ded672c3-1e54-4514-97ea-ef2ca3d4ffe6.jpg   30   54  41.81250
# Canny(triangle)  0ed6b6c7-fc8e-49a1-b077-7bddd2ee202f.jpg   29   53  38.43750
# Canny(triangle)  0e4c7385-c750-4cf6-9bfb-2818544b0d1d.jpg   55   91  69.37500
# Canny(triangle)  46c88d82-d909-4156-b198-79fd0571a983.jpg   21   54  36.68750
# ...                                                   ...  ...  ...       ...
# Canny(triangle)  f5744022-17de-4885-b35c-5f94b9c2a586.jpg   40   67  51.15625
# Canny(triangle)  f5382313-d332-471d-a5d1-629bb8e2e903.jpg   29   69  45.96875
# Canny(triangle)  0da44e1b-8158-40d4-a311-2fc016111d13.jpg   32   65  43.34375
# Canny(triangle)  0da46961-93dc-492c-b4d8-54d9b7e439fa.jpg   35   59  48.53125
# ...

# %%
#STOP

# %%
damage_sixteen_url = "damage/damage_sixteen.csv"
df_merge_sixteen = merge_df(df_damage_ringsranking_sixteen, df_damage_pine_sixteen, df_damage_fur_sixteen, df_damage_tracy_sixteen, df_damage_data_sixteen)
df_damage_sixteen = save_damage(damage_sixteen_url, df_merge_sixteen)
df_damage_sixteen
# Out:
#                                                                          image  \
# model
# Polar Pith Canny(blur otsu)  2-34e23370868237a073d086fb64851017e9b2c8c9_859...
# Polar Pith Canny(blur otsu)  1-5d205d5ea6bafd3c2e038cf1139cdd5a9825388f_275...
# Polar Pith Canny(blur otsu)  1-11c00bf7cc3e03dc86bde8a20c8ab390b0b2f2a4_d5d...
# Polar Pith Canny(blur otsu)  2-8c5de8aa63e57b1e5d3a11ce4c4e2ded042b2ef3_069...
# Polar Pith Canny(blur otsu)  1-3d78e56849a16c0b17831129f6059e367574a138_856...
# ...                                                                        ...
# Canny(triangle)                       f5744022-17de-4885-b35c-5f94b9c2a586.jpg
# Canny(triangle)                       f5382313-d332-471d-a5d1-629bb8e2e903.jpg
# Canny(triangle)                       0da44e1b-8158-40d4-a311-2fc016111d13.jpg
# Canny(triangle)                       0da46961-93dc-492c-b4d8-54d9b7e439fa.jpg
# Canny(triangle)                       55a25d98-1be0-43e2-af3f-75b6a993ef83.jpg
#
# ...

# %%
damage_thirtytwo_url = "damage/damage_thirtytwo.csv"
df_merge_thirtytwo = merge_df(df_damage_ringsranking_thirtytwo, df_damage_pine_thirtytwo, df_damage_fur_thirtytwo, df_damage_tracy_thirtytwo, df_damage_data_thirtytwo)
df_damage_thirtytwo = save_damage(damage_thirtytwo_url, df_merge_thirtytwo)
df_damage_thirtytwo
# Out:
#                                                                          image  \
# model
# Polar Pith Canny(blur otsu)  2-34e23370868237a073d086fb64851017e9b2c8c9_859...
# Polar Pith Canny(blur otsu)  1-5d205d5ea6bafd3c2e038cf1139cdd5a9825388f_275...
# Polar Pith Canny(blur otsu)  1-11c00bf7cc3e03dc86bde8a20c8ab390b0b2f2a4_d5d...
# Polar Pith Canny(blur otsu)  2-8c5de8aa63e57b1e5d3a11ce4c4e2ded042b2ef3_069...
# Polar Pith Canny(blur otsu)  1-3d78e56849a16c0b17831129f6059e367574a138_856...
# ...                                                                        ...
# Canny(triangle)                       f5744022-17de-4885-b35c-5f94b9c2a586.jpg
# Canny(triangle)                       f5382313-d332-471d-a5d1-629bb8e2e903.jpg
# Canny(triangle)                       0da44e1b-8158-40d4-a311-2fc016111d13.jpg
# Canny(triangle)                       0da46961-93dc-492c-b4d8-54d9b7e439fa.jpg
# Canny(triangle)                       55a25d98-1be0-43e2-af3f-75b6a993ef83.jpg
#
# ...

# %%
STOP
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 STOP
#
# NameError: name 'STOP' is not defined

# %%
mse_url = "output/all_mse_sixteen.csv"
rings_url = "output/all_rings_sixteen.csv"
df_all_sixteen = winner_model_rings(mse_url, rings_url)

df_damage_all_sixteen = damage(df_all_sixteen)
df_damage_all_sixteen

# %%
mse_url = "output/all_mse_thirtytwo.csv"
rings_url = "output/all_rings_thirtytwo.csv"
df_all_thirtytwo = winner_model_rings(mse_url, rings_url)

df_damage_all_thirtytwo = damage(df_all_thirtytwo)
df_damage_all_thirtytwo

# %%
#STOP

# %%
damage_sixteen_url = "damage/damage_all_sixteen.csv"
df_damage_sixteen = save_damage(damage_sixteen_url, df_damage_all_sixteen)
df_damage_sixteen

# %%
damage_thirtytwo_url = "damage/damage_all_thirtytwo.csv"
df_damage_thirtytwo = save_damage(damage_thirtytwo_url, df_damage_all_thirtytwo)
df_damage_thirtytwo

# %%
#STOP
